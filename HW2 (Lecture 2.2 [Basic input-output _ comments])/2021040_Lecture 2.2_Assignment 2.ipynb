# %% [markdown]
# ### You must try to solve first then you can take help from group member. This assignment is based on Lecture 2.2 and the previous lectures.

# %% [markdown]
# 1. You must write user friendly meaasge in input and output (if necessary).
#
# 2. Write comment when it needs
#
# 3. Use the variables names related to the problem.

# %% [markdown]
# 1. Take three numbers as input and find the sum of them.

# %%
a,b,c = map(int,input("Give 3 numbers: ").split())
sum = a+b+c
print("The sum of the 3 given numbers is", sum)
# Out:
# Give 3 numbers: 5 15 30
# The sum of the 3 given numbers is 50

# %% [markdown]
# 2. Take the radious of a circle as input and find the area of the circle. Answer should be 3 decimal point

# %%
import math
radius = int(input("Give radius: "))
area = math.pi*(radius**2)
print("The area of the circle is: %.3f" %area)
# Out:
# Give radius: 2
# The area of the circle is: 12.566

# %% [markdown]
# 3. Take two number as input by one input function and calculate their additiob, subtraction, multiplication and division.

# %%
a,b = map(int, input("GIve 2 numbers ").split())
addition = a+b
subtraction = a-b
multiplication = a*b
division = a/b
print("The sum of {0} and {1} is {2}".format(a,b,addition))
print("The sum of {0} and {1} is {2}".format(a,b,subtraction))
print("The sum of {0} and {1} is {2}".format(a,b,multiplication))
print("The sum of {0} and {1} is {2}".format(a,b,division))
# Out:
# GIve 2 numbers 6 3
# The sum of 6 and 3 is 9
# The sum of 6 and 3 is 3
# The sum of 6 and 3 is 18
# The sum of 6 and 3 is 2.0

# %% [markdown]
# 4. Input 3 float numbers and find their average and print like this. "the average of a,b and c is d", use any output formating

# %%
a,b,c = map(float, input("Give 3 numbers: ").split())
average = (a+b+c)/3
print("The average of {0}, {1} and {2} is {3}".format(a,b,c,average))
# Out:
# Give 3 numbers: 3.3 3.2 3.1
# The average of 3.3, 3.2 and 3.1 is 3.1999999999999997

# %% [markdown]
# 5. Take 3 integer and 3 float number and find the difference between the integers and floats.

# %%
a,b,c = map(int, input("Give 3 integar numbers: ").split())
d,e,f = map(float, input("Give 3 float numbers: ").split())
first_diff = a-d
second_diff = b-e
third_diff = c-f
print("The difference between {0} and {1} is {2}".format(a,d, first_diff))
print("The difference between {0} and {1} is {2}".format(b,e, second_diff))
print("The difference between {0} and {1} is {2}".format(c,f, third_diff))
# Out:
# Give 3 integar numbers: 3 2 1
# Give 3 float numbers: 2.5 1.5 0.5
# The difference between 3 and 2.5 is 0.5
# The difference between 2 and 1.5 is 0.5
# The difference between 1 and 0.5 is 0.5

# %% [markdown]
# 6. Input three string by one input function and make a sentence using the three string.

# %%
a,b,c = input("Give 3 word inputs: ").split()
print("{0} darkness {1} old {2}".format(a,b,c))
# Out:
# Give 3 word inputs: hello my friend
# hello darkness my old friend

# %% [markdown]
# 7. input 2 number as string, convert them to number, find their sum then convert the sum to string and print using format specifier.

# %%
a,b = input("Give 2 numbers: ").split()
print(type(a))
print(type(b))
c = int(a)
d = int(b)
print(type(c))
print(type(d))
sum = c+d
print("The sum of {0} & {1} is {2}".format(c,d,sum))
e = str(sum)
print(type(e))
# Out:
# Give 2 numbers: 3 4
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# The sum of 3 & 4 is 7
# <class 'str'>

# %% [markdown]
# 8. Print the following sentence using print function. you must print the double cotation of the sentences.
#
#            "Honesty is the best policy"

# %%
print('"'"Honesty is the best policy"'"')
# Out:
# "Honesty is the best policy"

# %% [markdown]
# 9. Print this sentence  =   "i like 'fish' and 'egg' but i haven't money to buy."

# %%
print( '"'+"i like"+"'"+"fish"+"'"+"and"+"'"+"egg"+"'" "but i haven't money to buy"+'"')
# Out:
# "i like'fish'and'egg'but i haven't money to buy"

# %% [markdown]
# 10. Write a code that represent all the systex of Lecture 2.2. You can use any kind of example.

# %%
'''I am using a code that requires the following things after taking two input from the user
addition of the two inputs
subtraction of the two inputs
multiplication of the two inputs
division of the two inputs
and also, takes 3 strings and places them in a sentence'''

a,b = map(int, input("GIve 2 numbers ").split())
x,y,z = input("Give 3 word inputs: ").split()
addition = a+b
subtraction = a-b
multiplication = a*b
division = a/b
print("The sum of {0} and {1} is {2}".format(a,b,addition))
print("The sum of {0} and {1} is {2}".format(a,b,subtraction))
print("The sum of {0} and {1} is {2}".format(a,b,multiplication))
print("The sum of {0} and {1} is {2}".format(a,b,division))
print("{0} darkness {1} old {2}".format(x,y,z))
# Out:
# GIve 2 numbers 9 3
# Give 3 word inputs: hello my friend
# The sum of 9 and 3 is 12
# The sum of 9 and 3 is 6
# The sum of 9 and 3 is 27
# The sum of 9 and 3 is 3.0
# hello darkness my old friend
