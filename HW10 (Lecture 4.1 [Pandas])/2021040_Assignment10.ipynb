# %% [markdown]
# ###### 1.   In the github Assignment section, you will get a data set named Assignment_10_data. Download the data and perform the following operation.

# %% [markdown]
# 1. import the data set
#
# 2. Show the full data set using python pandas function.
#
# 3. Create another data frame from given data set that contain only 2 columns. Also convert the data frame to CSV
#
# 4. Find out number of null values of the given data sets and also show the mean and standard deviation.
#
# 5. Create a data frame that contain the 51th to 120th row.
#
# 6. Make a new dataset that you get from 5 no

# %% [markdown]
# ## **1.** import the data set

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
downloaded = drive.CreateFile({'id':'1s5TyqQb2yLGZxyz77odkZTsTHLj86_21'}) # replace the id with id of file you want to access
downloaded.GetContentFile('Assignment_10_data.csv')

# %% [markdown]
# ## **2.** Show the full data set using python pandas function

# %%
import pandas as pd
df = pd.read_csv('Assignment_10_data.csv')
entire_file = df.to_string() 
print(entire_file)
# Out:
#                    Station_Names  YEAR  Month  Temprature     Rainfall
# 0                          Bogra  1948      1   25.800000     8.140625
# 1                          Bogra  1948      2   33.300000    11.140625
# 2                          Bogra  1948      3   38.300000    25.312500
# 3                          Bogra  1948      4   39.500000    69.140625
# 4                          Bogra  1948      5   36.100000   179.890625
# 5                          Bogra  1948      6   33.500000   315.578125
# 6                          Bogra  1948      7   33.100000   363.718750
# 7                          Bogra  1948      8   33.300000   307.015625
# 8                          Bogra  1948      9   34.700000   269.046875
# 9                          Bogra  1948     10   33.800000   145.984375
# 10                         Bogra  1948     11   31.900000    12.890625
# 11                         Bogra  1948     12   26.900000     6.390625
# ...

# %% [markdown]
# ## **3.** Create another data frame from given data set that contain only 2 columns. Also convert the data frame to CSV

# %%
df = pd.read_csv('Assignment_10_data.csv')
columns = df[['YEAR','Rainfall']]
join = pd.DataFrame(columns)
y = join.head()
print(y)
y.to_csv('top_data.csv')

# "top_data.csv" file link = https://drive.google.com/file/d/1fqC65ZPp4egmJxba5M3ExUjuxhUgqP4E/view?usp=sharing
# Out:
#    YEAR    Rainfall
# 0  1948    8.140625
# 1  1948   11.140625
# 2  1948   25.312500
# 3  1948   69.140625
# 4  1948  179.890625

# %% [markdown]
# ## **4.** Find out number of null values of the given data sets and also show the mean and standard deviation.

# %%
df = pd.read_csv('Assignment_10_data.csv')
print(df.info())
print('\n')
x = df.describe()
print(x)
#Mean
print('\n', "Mean :", '\n')
print(x.iloc[1])
print('\n')
#Standard deviation
print('\n', "Standard deviation :",'\n')
print(x.iloc[2])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21120 entries, 0 to 21119
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Station_Names  21120 non-null  object
#  1   YEAR           21120 non-null  int64
#  2   Month          21120 non-null  int64
#  3   Temprature     21120 non-null  float64
#  4   Rainfall       21120 non-null  float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 825.1+ KB
# None
#
#
#                YEAR         Month    Temprature      Rainfall
# count  21120.000000  21120.000000  21120.000000  21120.000000
# mean    1985.773295      6.500000     33.475129    197.529667
# std       17.604499      3.452134      2.986268    239.041031
# min     1948.000000      1.000000     21.600000      0.000000
# 25%     1972.000000      3.750000     31.700000      8.000000
# 50%     1988.000000      6.500000     33.900000    110.000000
# ...

# %% [markdown]
# ## **5.**    Create a data frame that contain the 51th to 120th row.
# ## **6.**    Make a new dataset that you get from 5 no

# %%
df = pd.read_csv('Assignment_10_data.csv')
p = df.loc[51:120, :]
print(p)
p.to_csv('New_datafile.csv')

# "New_datafile.csv" file link = https://drive.google.com/file/d/1fqC65ZPp4egmJxba5M3ExUjuxhUgqP4E/view?usp=sharing
# Out:
#     Station_Names  YEAR  Month  Temprature    Rainfall
# 51       Faridpur  1948      4        35.8  245.000000
# 52       Faridpur  1948      5        33.9  324.000000
# 53       Faridpur  1948      6        33.9  402.000000
# 54       Faridpur  1948      7        32.3  359.000000
# 55       Faridpur  1948      8        31.5  410.000000
# ..            ...   ...    ...         ...         ...
# 116     Srimangal  1948      9        33.7  247.646154
# 117     Srimangal  1948     10        33.5  162.953846
# 118     Srimangal  1948     11        31.2   38.123077
# 119     Srimangal  1948     12        27.4    6.953846
# 120       Barisal  1949      1        29.4    0.000000
#
# [70 rows x 5 columns]

# %%
p.shape
# Out:
# (70, 5)

# %%
p["YEAR"].count()
# Out:
# 70

# %% [markdown]
# ###### 2. Create a data frame that contain Id, Name, Department, Result of minimum 5 persons. Then convert the data frame to a CSV file and excel file.

# %%
import pandas as pd

d = {'ids':[2014135045,2014135003,2014135006,2014135009,2014135012,2014135013,2014135018,2014135030],'names':['Md. Rezuwan Hassan', 'Zohaer Abtahi', 'Muhtasim Rushdi', 'Rawfur Nahar Rawfu', 'Monisha Tasnim', 'Sadman Sakib Bhuiyan', 'Sifat Munir','Priyanka Das Pinku'],'Department':['GEE','GEE','GEE','GEE','GEE','GEE','GEE','GEE'],'Result':[3.45, 3.55, 3.65, 3.75, 3.85,3.95,3.98,4.00],}
df = pd.DataFrame(d)
print(df)

df.to_csv('SUST_2014-15_GEE_Students.csv')
df.to_excel('SUST_2014-15_GEE_Students.xlsx')
ie
# "SUST_2014-15_GEE_Students.csv" file link = https://drive.google.com/file/d/1NEDXdCU8GVhhOdIS-0k-U12AXQD_GccM/vw?usp=sharing
# "SUST_2014-15_GEE_Students.xlsx" file link = https://docs.google.com/spreadsheets/d/1p1tUq3UuGWa9Wop4_v_FS5H6YvYAzuoq/edit?usp=sharing&ouid=117990355164622980805&rtpof=true&sd=true
# Out:
#           ids                 names Department  Result
# 0  2014135045    Md. Rezuwan Hassan        GEE    3.45
# 1  2014135003         Zohaer Abtahi        GEE    3.55
# 2  2014135006       Muhtasim Rushdi        GEE    3.65
# 3  2014135009    Rawfur Nahar Rawfu        GEE    3.75
# 4  2014135012        Monisha Tasnim        GEE    3.85
# 5  2014135013  Sadman Sakib Bhuiyan        GEE    3.95
# 6  2014135018           Sifat Munir        GEE    3.98
# 7  2014135030    Priyanka Das Pinku        GEE    4.00

# %% [markdown]
# ###### 3. Import the excel file and perform the operation that is given in the previous question.

# %% [markdown]
# ## **1.** import the data set

# %%
downloaded = drive.CreateFile({'id':'1p1tUq3UuGWa9Wop4_v_FS5H6YvYAzuoq'}) # replace the id with id of file you want to access
downloaded.GetContentFile("SUST_2014-15_GEE_Students.xlsx")

# %% [markdown]
# ## **2.** Show the full data set using python pandas function

# %%
import pandas as pd
df = pd.read_excel('SUST_2014-15_GEE_Students.xlsx')
entire_file = df.to_string()
print(entire_file)
# Out:
#    Unnamed: 0         ids                 names Department  Result
# 0           0  2014135045    Md. Rezuwan Hassan        GEE    3.45
# 1           1  2014135003         Zohaer Abtahi        GEE    3.55
# 2           2  2014135006       Muhtasim Rushdi        GEE    3.65
# 3           3  2014135009    Rawfur Nahar Rawfu        GEE    3.75
# 4           4  2014135012        Monisha Tasnim        GEE    3.85
# 5           5  2014135013  Sadman Sakib Bhuiyan        GEE    3.95
# 6           6  2014135018           Sifat Munir        GEE    3.98
# 7           7  2014135030    Priyanka Das Pinku        GEE    4.00

# %% [markdown]
# ## **3.** Create another data frame from given data set that contain only 2 columns. Also convert the data frame to CSV

# %%
import pandas as pd
df = pd.read_excel('SUST_2014-15_GEE_Students.xlsx')
data = df[['ids','names']] 
dataframe = pd.DataFrame(data)
print(dataframe)
# Out:
#           ids                 names
# 0  2014135045    Md. Rezuwan Hassan
# 1  2014135003         Zohaer Abtahi
# 2  2014135006       Muhtasim Rushdi
# 3  2014135009    Rawfur Nahar Rawfu
# 4  2014135012        Monisha Tasnim
# 5  2014135013  Sadman Sakib Bhuiyan
# 6  2014135018           Sifat Munir
# 7  2014135030    Priyanka Das Pinku

# %% [markdown]
# ## **4.** Find out number of null values of the given data sets and also show the mean and standard deviation.

# %%
import pandas as pd
df = pd.read_excel('SUST_2014-15_GEE_Students.xlsx')
df.info()
print('\n')
x = df.describe()
print(x)

#Mean
print('\n')
print('\n','Mean')
print('\n')
a = df.iloc[1]
print(a)

#Standard deviation
print('\n')
print('\n','Standard deviation')
print('\n')
b = df.iloc[2]
print(b)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  8 non-null      int64
#  1   ids         8 non-null      int64
#  2   names       8 non-null      object
#  3   Department  8 non-null      object
#  4   Result      8 non-null      float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 448.0+ bytes
#
#
#        Unnamed: 0           ids    Result
# count     8.00000  8.000000e+00  8.000000
# mean      3.50000  2.014135e+09  3.772500
# std       2.44949  1.402039e+01  0.207485
# min       0.00000  2.014135e+09  3.450000
# 25%       1.75000  2.014135e+09  3.625000
# 50%       3.50000  2.014135e+09  3.800000
# 75%       5.25000  2.014135e+09  3.957500
# max       7.00000  2.014135e+09  4.000000
#
#
#
#  Mean
#
#
# Unnamed: 0                1
# ids              2014135003
# names         Zohaer Abtahi
# ...

# %% [markdown]
# ## **5.**    Create a data frame that contain the 2nd to 5th row.
# ## **6.**    Make a new dataset that you get from 5 no

# %%
import pandas as pd
df = pd.read_excel('SUST_2014-15_GEE_Students.xlsx')
x = df.loc[2:5,:]
print(x)
x.to_csv('New_datafile2.csv')
# "New_datafile2.csv" file link = https://drive.google.com/file/d/1-PXSUprzYS3_f5JkQGSwIkbmNxKm4_BL/view?usp=sharing
# Out:
#    Unnamed: 0         ids                 names Department  Result
# 2           2  2014135006       Muhtasim Rushdi        GEE    3.65
# 3           3  2014135009    Rawfur Nahar Rawfu        GEE    3.75
# 4           4  2014135012        Monisha Tasnim        GEE    3.85
# 5           5  2014135013  Sadman Sakib Bhuiyan        GEE    3.95
