# %%
# 1. Print your name using python.

print("Md. Rezuwan Hassan")
# Out:
# Md. Rezuwan Hassan

# %%
# 2. A = 15, B = 25, now print A and B

A = 15
B = 25
print(A)
print(B)
# Out:
# 15
# 25

# %%
# 3. Take three variables and take three number on it and print the numbers.

a = 3
b = 6
c = 9
print("a" = a)
print("b" = b)
print("c" = c)
# Out:
#   File "<ipython-input-4-05096bce6186>", line 6
#     print("a" = a)
#          ^
# SyntaxError: keyword can't be an expression

# %%
# Take two numbers and find their multiplication and print it.

a = 2
b = 3
c = a*b
print( "a*b =", c)
# Out:
# a*b = 6

# %%
# 5. Take two float number and divide the first number by the second number and print the answer.

a = 7.5
b = 2.5
c = a/b
print("a/b =", c)
# Out:
# a/b = 3.0

# %%
# 6. Take two number and print their type, then find their sum and also print the type of the sum.

a = 2
b = 3
c = a+b
print(type(a))
print(type(b))
print(type(c))
print("a+b =", c)
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# a+b = 5

# %%
# 7. Take 2 float numbers and find the addition, subtraction, multiplication and devision of the two numbers.

a = 7.5
b = 2.5
c = a/b
d = a-b
e = a*b
f = a/b
print("Addition of a & b is =", c)
print("subtraction of a & b is =", d)
print("multiplication of a & b is =", e)
print("division of a & b is =", f)
# Out:
# Addition of a & b is = 3.0
# subtraction of a & b is = 5.0
# multiplication of a & b is = 18.75
# division of a & b is = 3.0

# %%
# 8. Take three number and find their average.

a = 2
b = 4
c = 6
d = (a+b+c)/3
print("Average of a, b & c is =", d)
# Out:
# Average of a, b & c is = 4.0

# %%
# 9. Take one float and one int number and perform division operation between them.

a = 13
b = 6.5
c = a/b
print("a/b =", c)
# Out:
# a/b = 2.0

# %%
# 10. Take two number as string, convert them to int and find their sum.

a = str(2)
b = str(3)

c = int(a)
d = int(b)

e = c+d

print("sum of the two numbers is =", e)
# Out:
# sum of the two numbers is = 5
