# %% [markdown]
# ###### This assignment is based on Lecture 2.3 and the previous lectures. Before solve the problem, you must watch the video lectures first and know the syntax.

# %% [markdown]
# 1. Take two number as input using one input function and calculate the sum of them and check the sum is 45 or not using identity operators.

# %%
a, b = map(int, input("Insert two variables: ").split())
c = a+b
print(45 is c)
# Out:
# Insert two variables: 44 1
# True

# %% [markdown]
# 2. Input two string and check both are same or not, in  here you must use identity and comparison operator seperately.

# %%
a,b = input("Insert 2 strings: ").split()
if (a == b):
  print("Using comparison operators, We see that both strings are same")
else:
  print("Using comparison operators, We see that both strings are not same")

a is b
# Out:
# Insert 2 strings: bux bux
# Using comparison operators, We see that both strings are same
# False

# %% [markdown]
# 3. Input two number as string and consider the first one as base and perform exponent operation on it.

# %%
a,b = input("Insert 2 numbers: ").split()
a = int(a)
b = int(b)
c = a**b
print("Performing exponent operation on the first one as base and second one as power, we get =", c)
# Out:
# Insert 2 numbers: 5 3
# Performing exponent operation on the first one as base and second one as power, we get = 125

# %% [markdown]
# 4. Input two number and find the difference between the division and floor division of both numbers.

# %%
a,b = map(int, input("Insert two numbers: ").split())
c = a/b
d = a//b
e = c-d
print("The difference between the division and floor division of the both numbers is: ", e)
# Out:
# Insert two numbers: 10 3
# The difference between the division and floor division of the both numbers is:  0.3333333333333335

# %% [markdown]
# 5. Take a string like "Online free course:: Python for research" and check the word 'python' is in the sentence or not.

# %%
a = "Online free course:: Python for research"
b = "python"
if b in a:
  print("The word 'python' is in the sentence 'Online free course:: Python for research'")
else:
  print("The word 'python' is not in the sentence 'Online free course:: Python for research'")
# Out:
# The word 'python' is not in the sentence 'Online free course:: Python for research'

# %% [markdown]
# 6. Take two numbers as input and consider one number as base of a traingle and one as hight and calculte the area, also consider the numbers  as length and width of rectangle and find the area and find the truth value, weather area of traingle is half of the area of rectangle or not.

# %%
a = int(input("Insert Base/Length: "))
b = int(input("Insert Height/Width: "))
t = 0.5*a*b
r = a*b
x = 0.5*r
t == x
# Out:
# Insert Base/Length: 3
# Insert Height/Width: 4
# True

# %% [markdown]
# 7. Take two numbers as input and find the modular division of the first number by the second one and also find the truth value that the remainder is greather than 5 or not.

# %%
a,b = map(float, input("Insert two numbers: ").split())
c = a%b
c > 5
# Out:
# Insert two numbers: 102 14
# False

# %% [markdown]
# 8. Take one string and one number as input and add the string with the number.

# %%
a = input("Insert a string: ")
b =input("Insert a number: ")
c = a+b
print(c)
# Out:
# Insert a string: string
# Insert a number: 0
# string0

# %% [markdown]
# 9. Take two numbers and perform all betwise operation and show the result. You must write the binary values as a comment when necessary

# %%
a,b,x = map(int, input("Insert three numbers: ").split())
c = a & b  #1010 & 0111 = 0010 = 2
d = a | b  #1010 | 0111 = 1111 = 15
e = a ^ b  #1010 ^ 0111 = 1101 = 13
f = ~a     #~1010 = -(1010+1) = -1011 = -11
g = a >> x #1010 >> 2 = 10 = 2
h = a << x #1010 << 2 = 101000 = 40
print("bitwise'AND'operation between the two numbers is =", c) 
print("bitwise'OR'operation between the two numbers is =", d)
print("bitwise'XOR'operation between the two numbers is =", e)
print("bitwise'ONE'S COMPLIMENT'operation on the first number is =", f)
print("bitwise'RIGHT SHIFT'operation between the first and last two numbers is =", g)
print("bitwise'LEFT SHIFT'operation between the first and last two numbers is =", h)
# Out:
# Insert three numbers: 10 7 2
# bitwise'AND'operation between the two numbers is = 2
# bitwise'OR'operation between the two numbers is = 15
# bitwise'XOR'operation between the two numbers is = 13
# bitwise'ONE'S COMPLIMENT'operation on the first number is = -11
# bitwise'RIGHT SHIFT'operation between the first and last two numbers is = 2
# bitwise'LEFT SHIFT'operation between the first and last two numbers is = 40

# %% [markdown]
# 10. Write a python program that contain the operatrs that are discussed in
# Lecture 2.3

# %%
a,b = map(int, input("Insert two numbers: ").split())

#Arithmatic operators
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a**b)
print(a//b)

#Comaprison operators
print(a==b)
print(a!=b)
print(a <=b)
print(a >= b)
print(a>b)
print(a<b)

#Logical operators
print(a>2 and b <12)
print(a>2 or b <2)

#Membership operator
x = "Man is mortal"
"Man" in x
"mortal" not in x

#Identity operators
print(a is b)
print(a is not b)

#Bitwise operators
print(a&b)
print(a|b)
print(a^b)
print(~a)
print(a<<b)
print(a>>b)

#Assignment operator

p = 10
q = 1

p += q
print(p)
p -= q
print(p)
# Out:
# Insert two numbers: 10 7
# 17
# 3
# 70
# 1.4285714285714286
# 3
# 10000000
# 1
# False
# True
# False
# True
# True
# False
# True
# True
# False
# True
# 2
# 15
# 13
# -11
# 1280
# 0
# 11
# 10

# %%
10 7
